# %% [markdown]
# # Try Apache Beam - Python
#
# In this notebook, we set up your development environment and work through a simple example using the [DirectRunner](https://beam.apache.org/documentation/runners/direct/). You can explore other runners with the [Beam Capatibility Matrix](https://beam.apache.org/documentation/runners/capability-matrix/).
#
# To navigate through different sections, use the table of contents. From **View**  drop-down list, select **Table of contents**.
#
# To run a code cell, you can click the **Run cell** button at the top left of the cell, or by select it and press **`Shift+Enter`**. Try modifying a code cell and re-running it to see what happens.
#
# To learn more about Colab, see [Welcome to Colaboratory!](https://colab.sandbox.google.com/notebooks/welcome.ipynb).

# %% [markdown]
# # Setup
#
# First, you need to set up your environment, which includes installing `apache-beam` and downloading a text file from Cloud Storage to your local file system. We are using this file to test your pipeline.

# %%
# !pip install apache-beam
# Out:
# Collecting apache-beam
#   Downloading apache_beam-2.69.0.tar.gz (2.9 MB)
#      |████████████████████████████████| 2.9 MB 3.1 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 8.2 MB/s eta 0:00:01
# Collecting objsize<0.8.0,>=0.6.1
#   Downloading objsize-0.7.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz>=2018.3 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (2025.2)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (4.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=3.12 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (6.0.3)
# Collecting pydot<2,>=1.2.0
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting jsonpickle<4.0.0,>=3.0.0
#   Downloading jsonpickle-3.4.2-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 21.7 MB/s eta 0:00:01
# Collecting crcmod<2.0,>=1.7
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      |████████████████████████████████| 89 kB 17.1 MB/s eta 0:00:01
# Collecting cryptography<48.0.0,>=39.0.0
#   Using cached cryptography-46.0.3-cp38-abi3-macosx_10_9_universal2.whl (7.2 MB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (4.25.1)
# Collecting pymongo<5.0.0,>=3.8.0
#   Downloading pymongo-4.15.3-cp39-cp39-macosx_11_0_arm64.whl (757 kB)
#      |████████████████████████████████| 757 kB 11.8 MB/s eta 0:00:01
# Collecting httplib2<0.23.0,>=0.8
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 36.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2.3.0,>=1.14.3 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (2.0.2)
# Collecting orjson<4,>=3.9.7
#   Using cached orjson-3.11.4-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (243 kB)
# Collecting grpcio!=1.48.0,!=1.59.*,!=1.60.*,!=1.61.*,!=1.62.0,!=1.62.1,<1.66.0,<2,>=1.33.1
#   Downloading grpcio-1.65.5-cp39-cp39-macosx_10_9_universal2.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 48.4 MB/s eta 0:00:01
# Collecting pyarrow-hotfix<1
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.25.0-cp39-cp39-macosx_11_0_arm64.whl (640 kB)
#      |████████████████████████████████| 640 kB 29.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (2.9.0.post0)
# Collecting beartype<0.22.0,>=0.21.0
#   Downloading beartype-0.21.0-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 19.2 MB/s eta 0:00:01
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<7.0.0.dev0,>=3.20.3
#   Using cached protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Collecting redis<6,>=5.0.0
#   Downloading redis-5.3.1-py3-none-any.whl (272 kB)
#      |████████████████████████████████| 272 kB 24.5 MB/s eta 0:00:01
# Collecting pyarrow<19.0.0,>=3.0.0
#   Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_arm64.whl (29.5 MB)
#      |████████████████████████████████| 29.5 MB 17.6 MB/s eta 0:00:01
# Collecting regex>=2020.6.8
#   Downloading regex-2025.10.23-cp39-cp39-macosx_11_0_arm64.whl (288 kB)
#      |████████████████████████████████| 288 kB 95.4 MB/s eta 0:00:01
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.20-py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (2.32.5)
# Collecting sortedcontainers>=2.4.0
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 43.0 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=22.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from apache-beam) (25.0)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.12.1-cp39-cp39-macosx_10_9_universal2.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 12.5 MB/s eta 0:00:01
# Requirement already satisfied: cffi>=2.0.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from cryptography<48.0.0,>=39.0.0->apache-beam) (2.0.0)
# Requirement already satisfied: pycparser in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from cffi>=2.0.0->cryptography<48.0.0,>=39.0.0->apache-beam) (2.23)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: six>=1.9.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam) (1.17.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from httplib2<0.23.0,>=0.8->apache-beam) (3.2.5)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (2025.9.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (25.4.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->apache-beam) (0.36.2)
# Collecting dnspython<3.0.0,>=1.16.0
#   Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Collecting PyJWT>=2.9.0
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting async-timeout>=4.0.3
#   Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (2025.10.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/priyanka/Desktop/MLOPs/MLOps/lab_01/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.4->apache-beam) (2.5.0)
# Using legacy 'setup.py install' for crcmod, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for hdfs, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for docopt, since package 'wheel' is not installed.
# Building wheels for collected packages: apache-beam
#   Building wheel for apache-beam (PEP 517) ... done
#   Created wheel for apache-beam: filename=apache_beam-2.69.0-cp39-cp39-macosx_10_9_universal2.whl size=7923819 sha256=4618e96f6ef3c019d178849dfea7b9f74b2a53f487dbf60649e6bd934d0b1098
#   Stored in directory: /Users/priyanka/Library/Caches/pip/wheels/3d/88/32/015f929a0518bb472e7b25af0c10c120c0e742a8b21435d615
# Successfully built apache-beam
# Installing collected packages: PyJWT, protobuf, docopt, dnspython, async-timeout, zstandard, sortedcontainers, regex, redis, pymongo, pydot, pyarrow-hotfix, pyarrow, proto-plus, orjson, objsize, jsonpickle, httplib2, hdfs, grpcio, fasteners, fastavro, cryptography, crcmod, beartype, apache-beam
#     Running setup.py install for docopt ... done
#     Running setup.py install for hdfs ... done
#     Running setup.py install for crcmod ... done
# Successfully installed PyJWT-2.10.1 apache-beam-2.69.0 async-timeout-5.0.1 beartype-0.21.0 crcmod-1.7 cryptography-46.0.3 dnspython-2.7.0 docopt-0.6.2 fastavro-1.12.1 fasteners-0.20 grpcio-1.65.5 hdfs-2.7.3 httplib2-0.22.0 jsonpickle-3.4.2 objsize-0.7.1 orjson-3.11.4 proto-plus-1.26.1 protobuf-6.33.0 pyarrow-18.1.0 pyarrow-hotfix-0.7 pydot-1.4.2 pymongo-4.15.3 redis-5.3.1 regex-2025.10.23 sortedcontainers-2.4.0 zstandard-0.25.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/priyanka/Desktop/MLOPs/MLOps/lab_01/bin/python3 -m pip install --upgrade pip' command.

# %%
# Run and print a shell command.
def run(cmd):
  print('>> {}'.format(cmd))
  # !{cmd}
  print('')

# Install apache-beam.
# run('pip install --quiet apache-beam')

# Copy the input file into the local file system.
run('mkdir -p data')
run('gsutil cp gs://dataflow-samples/shakespeare/kinglear.txt data/')
# Out:
# >> mkdir -p data
#
# >> gsutil cp gs://dataflow-samples/shakespeare/kinglear.txt data/
# zsh:1: command not found: gsutil

# %% [markdown]
# # Word count with comments
#
# Below is mostly the same code as above, but with comments explaining every line in more detail.

# %%
import apache_beam as beam
import re

inputs_pattern = 'data/*'
outputs_prefix = 'outputs/part'

# Running locally in the DirectRunner.
with beam.Pipeline() as pipeline:
  # Store the word counts in a PCollection.
  # Each element is a tuple of (word, count) of types (str, int).
  word_counts = (
      # The input PCollection is an empty pipeline.
      pipeline

      # Read lines from a text file.
      | 'Read lines' >> beam.io.ReadFromText(inputs_pattern)
      # Element type: str - text line

      # Use a regular expression to iterate over all words in the line.
      # FlatMap will yield an element for every element in an iterable.
      | 'Find words' >> beam.FlatMap(lambda line: re.findall(r"[a-zA-Z']+", line))
      # Element type: str - word

      # Create key-value pairs where the value is 1, this way we can group by
      # the same word while adding those 1s and get the counts for every word.
      | 'Pair words with 1' >> beam.Map(lambda word: (word, 1))
      # Element type: (str, int) - key: word, value: 1

      # Group by key while combining the value using the sum() function.
      | 'Group and sum' >> beam.CombinePerKey(sum)
      # Element type: (str, int) - key: word, value: counts
  )

  # We can process a PCollection through other pipelines too.
  (
      # The input PCollection is the word_counts created from the previous step.
      word_counts

      # Format the results into a string so we can write them to a file.
      | 'Format results' >> beam.Map(lambda word_count: str(word_count))
      # Element type: str - text line

      # Finally, write the results to a file.
      | 'Write results' >> beam.io.WriteToText(outputs_prefix)
  )

# Sample the first 20 results, remember there are no ordering guarantees.
run('head -n 200 {}-00000-of-*'.format(outputs_prefix))
# Out:
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d
# >> head -n 200 outputs/part-00000-of-*
# ('KING', 243)
# ('LEAR', 236)
# ('DRAMATIS', 1)
# ('PERSONAE', 1)
# ('king', 65)
# ('of', 447)
# ('Britain', 2)
# ('OF', 15)
# ('FRANCE', 10)
# ('DUKE', 3)
# ('BURGUNDY', 8)
# ('CORNWALL', 63)
# ('ALBANY', 67)
# ('EARL', 2)
# ('KENT', 156)
# ('GLOUCESTER', 141)
# ('EDGAR', 126)
# ('son', 29)
# ('to', 438)
# ('Gloucester', 26)
# ('EDMUND', 99)
# ('bastard', 7)
# ('CURAN', 6)
# ('a', 366)
# ('courtier', 1)
# ('Old', 13)
# ('Man', 11)
# ('tenant', 3)
